# %% [markdown]
# # Create SRA submission sheet
# This Python Jupyter notebook creates a BioSample submission sheet for the Sequence Read Archive:
#
# First, import Python modules:

# %%
import datetime
import glob
import itertools
import os

import natsort

import pandas as pd

import yaml

# %% [markdown]
# Display full columns of data frames:

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Read the configuration for the uploads:

# %%
with open('upload_config.yaml') as f:
    config = yaml.safe_load(f)

# %% [markdown]
# Read the Illumina runs to submit:

# %%
print(f"Reading Illumina runs from {config['barcode_runs']}")

illumina_runs = pd.read_csv(config['barcode_runs'])

print('Here are the first few entries in the Illumina runs:')
illumina_runs.head()
# Out:
# Reading Illumina runs from ../data/barcode_runs.csv
# Here are the first few entries in the Illumina runs:
#   library                       sample    date  experiment antibody  \
# 0    lib1  expt_24-33-none-0-reference  200904  expt_24-33     none
# 1    lib2  expt_24-33-none-0-reference  200904  expt_24-33     none
# 2    lib1  expt_82-86-none-0-reference  210115  expt_82-86     none
# 3    lib2  expt_82-86-none-0-reference  210115  expt_82-86     none
# 4    lib1       expt_27-CB6-400-escape  200904     expt_27      CB6
#
#    concentration concentration_units           group  selection  frac_escape  \
# 0              0           ng_per_mL  clinical_serum  reference          NaN
# 1              0           ng_per_mL  clinical_serum  reference          NaN
# 2              0           ng_per_mL        Baker+LY  reference          NaN
# 3              0           ng_per_mL        Baker+LY  reference          NaN
# 4            400           ng_per_mL  clinical_serum     escape        0.222
#
#    cells_sorted  \
# 0   160000000.0
# 1   160000000.0
# 2           NaN
# 3           NaN
# 4     1907893.0
#
#                                                                                                                                                                                                                                                                    R1
# 0                                                                                                                                            /shared/ngs/illumina/agreaney/200914_D00300_1050_AHH3MTBCX3/Unaligned/Project_agreaney/expt_24-33_lib1_ref_*R1*.fastq.gz
# 1                                                                                                                                            /shared/ngs/illumina/agreaney/200914_D00300_1050_AHH3MTBCX3/Unaligned/Project_agreaney/expt_24-33_lib2_ref_*R1*.fastq.gz
# 2                                                                                                                                                    /shared/ngs/illumina/tstarr/210119_D00300_1157_AHK3HNBCX3/Unaligned/Project_tstarr/expt_82-86_lib1_ref*.fastq.gz
# 3                                                                                                                                                    /shared/ngs/illumina/tstarr/210119_D00300_1157_AHK3HNBCX3/Unaligned/Project_tstarr/expt_82-86_lib2_ref*.fastq.gz
# 4  /shared/ngs/illumina/agreaney/201012_D00300_1079_BHHV7TBCX3/Unaligned/Project_agreaney_lane1/expt_27_lib1_abneg_*R1*.fastq.gz; /fh/fast/bloom_j/SR/ngs/illumina/agreaney/200928_D00300_1067_BHHNHWBCX3/Unaligned/Project_agreaney/expt_27_lib1_abneg_*R1*.fastq.gz

# %% [markdown]
# Next make submission entries for the barcode runs, initially in "tidy" format with one FASTQ file per row:

# %%
submissions_tidy = (
    illumina_runs
    .assign(
        biosample_accession=lambda x: config['biosample_accession'],
        library_ID=lambda x: x['library'] + '_' + x['sample'],
        title=lambda x: 'SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for ' + x['sample'],
        library_strategy='AMPLICON',
        library_source='SYNTHETIC',
        library_selection='PCR',
        library_layout='single',
        platform='ILLUMINA',
        instrument_model='Illumina HiSeq 2500',
        design_description='PCR of barcodes from RBD variants',
        filetype='fastq',
        filename_fullpath=lambda x: x['R1'].str.split(';')
                                    .map(lambda flist: list(itertools.chain.from_iterable(glob.glob(f) for f in flist))),       
        )
    .explode('filename_fullpath')
    .assign(filename_fullpath=lambda x: x['filename_fullpath'].str.strip(),
            filename=lambda x: x['filename_fullpath'].map(os.path.basename))
    .drop(columns=illumina_runs.columns)
    .reset_index(drop=True)
    )

assert submissions_tidy['filename_fullpath'].map(os.path.isfile).all()

print('Here are the first few submission entries in tidy format:')
submissions_tidy.head()
# Out:
# Here are the first few submission entries in tidy format:
#   biosample_accession                        library_ID  \
# 0        SAMN17836431  lib1_expt_24-33-none-0-reference
# 1        SAMN17836431  lib2_expt_24-33-none-0-reference
# 2        SAMN17836431  lib1_expt_82-86-none-0-reference
# 3        SAMN17836431  lib1_expt_82-86-none-0-reference
# 4        SAMN17836431  lib1_expt_82-86-none-0-reference
#
#                                                                                          title  \
# 0  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_24-33-none-0-reference
# 1  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_24-33-none-0-reference
# 2  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_82-86-none-0-reference
# 3  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_82-86-none-0-reference
# 4  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_82-86-none-0-reference
#
#   library_strategy library_source library_selection library_layout  platform  \
# 0         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 1         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 2         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 3         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 4         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
#
#       instrument_model                 design_description filetype  \
# 0  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 1  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 2  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 3  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 4  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
#
#                                                                                                                filename_fullpath  \
# 0  /shared/ngs/illumina/agreaney/200914_D00300_1050_AHH3MTBCX3/Unaligned/Project_agreaney/expt_24-33_lib1_ref_S1_R1_001.fastq.gz
# 1  /shared/ngs/illumina/agreaney/200914_D00300_1050_AHH3MTBCX3/Unaligned/Project_agreaney/expt_24-33_lib2_ref_S2_R1_001.fastq.gz
# 2    /shared/ngs/illumina/tstarr/210119_D00300_1157_AHK3HNBCX3/Unaligned/Project_tstarr/expt_82-86_lib1_ref3_S79_R1_001.fastq.gz
# 3    /shared/ngs/illumina/tstarr/210119_D00300_1157_AHK3HNBCX3/Unaligned/Project_tstarr/expt_82-86_lib1_ref4_S80_R1_001.fastq.gz
# 4    /shared/ngs/illumina/tstarr/210119_D00300_1157_AHK3HNBCX3/Unaligned/Project_tstarr/expt_82-86_lib1_ref2_S78_R1_001.fastq.gz
#
#                                    filename
# 0    expt_24-33_lib1_ref_S1_R1_001.fastq.gz
# 1    expt_24-33_lib2_ref_S2_R1_001.fastq.gz
# 2  expt_82-86_lib1_ref3_S79_R1_001.fastq.gz
# 3  expt_82-86_lib1_ref4_S80_R1_001.fastq.gz
# 4  expt_82-86_lib1_ref2_S78_R1_001.fastq.gz

# %% [markdown]
# For the actual submission, we need a "wide" data frame that for each unique `sample_name` / `library_ID` gives all of the files each in different columns.
# These should be files without the full path.
#
# First, look at how many files there are for each sample / library:

# %%
(submissions_tidy
 .groupby(['biosample_accession', 'library_ID'])
 .aggregate(n_files=pd.NamedAgg('filename_fullpath', 'count'))
 .sort_values('n_files', ascending=False)
 .reset_index()
 )
# Out:
#   biosample_accession                                   library_ID  n_files
# 0        SAMN17836431             lib1_expt_82-86-none-0-reference        4
# 1        SAMN17836431             lib2_expt_82-86-none-0-reference        4
# 2        SAMN17836431             lib1_expt_24-33-none-0-reference        1
# 3        SAMN17836431                  lib1_expt_27-CB6-400-escape        1
# 4        SAMN17836431            lib1_expt_82-LY-CoV555-400-escape        1
# 5        SAMN17836431  lib1_expt_83-LY-CoV555+LY-CoV016-400-escape        1
# 6        SAMN17836431             lib2_expt_24-33-none-0-reference        1
# 7        SAMN17836431                  lib2_expt_27-CB6-400-escape        1
# 8        SAMN17836431            lib2_expt_82-LY-CoV555-400-escape        1
# 9        SAMN17836431  lib2_expt_83-LY-CoV555+LY-CoV016-400-escape        1

# %% [markdown]
# Now make the wide submission data frame.
# Note we keep only the filename column with the path lacking the full directory information:

# %%
submissions_wide = (
    submissions_tidy
    .assign(
        filename_count=lambda x: x.groupby(['biosample_accession', 'library_ID'])['filename'].cumcount() + 1,
        filename_col=lambda x: 'filename' + x['filename_count'].map(lambda c: str(c) if c > 1 else '')
        )
    .pivot(
        index='library_ID',
        columns='filename_col',
        values='filename',
        )
    )

submissions_wide = (
    submissions_tidy
    .drop(columns=['filename_fullpath', 'filename'])
    .drop_duplicates()
    .merge(submissions_wide[natsort.natsorted(submissions_wide.columns)],
           on='library_ID',
           validate='one_to_one',
           )
    )

print('Here are the first few submission entries in wide format:')
submissions_wide.head()
# Out:
# Here are the first few submission entries in wide format:
#   biosample_accession                        library_ID  \
# 0        SAMN17836431  lib1_expt_24-33-none-0-reference
# 1        SAMN17836431  lib2_expt_24-33-none-0-reference
# 2        SAMN17836431  lib1_expt_82-86-none-0-reference
# 3        SAMN17836431  lib2_expt_82-86-none-0-reference
# 4        SAMN17836431       lib1_expt_27-CB6-400-escape
#
#                                                                                          title  \
# 0  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_24-33-none-0-reference
# 1  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_24-33-none-0-reference
# 2  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_82-86-none-0-reference
# 3  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_82-86-none-0-reference
# 4       SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_27-CB6-400-escape
#
#   library_strategy library_source library_selection library_layout  platform  \
# 0         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 1         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 2         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 3         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 4         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
#
#       instrument_model                 design_description filetype  \
# 0  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 1  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 2  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 3  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 4  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
#
#                                      filename  \
# 0      expt_24-33_lib1_ref_S1_R1_001.fastq.gz
# 1      expt_24-33_lib2_ref_S2_R1_001.fastq.gz
# 2    expt_82-86_lib1_ref3_S79_R1_001.fastq.gz
# 3    expt_82-86_lib2_ref4_S84_R1_001.fastq.gz
# 4  expt_27_lib1_abneg_S7_L001_R1_001.fastq.gz
#
#                                   filename2  \
# 0                                       NaN
# 1                                       NaN
# 2  expt_82-86_lib1_ref4_S80_R1_001.fastq.gz
# 3  expt_82-86_lib2_ref3_S83_R1_001.fastq.gz
# 4                                       NaN
#
#                                   filename3  \
# 0                                       NaN
# 1                                       NaN
# 2  expt_82-86_lib1_ref2_S78_R1_001.fastq.gz
# 3  expt_82-86_lib2_ref1_S81_R1_001.fastq.gz
# 4                                       NaN
#
#                                   filename4
# 0                                       NaN
# 1                                       NaN
# 2  expt_82-86_lib1_ref1_S77_R1_001.fastq.gz
# 3  expt_82-86_lib2_ref2_S82_R1_001.fastq.gz
# 4                                       NaN

# %% [markdown]
# Now write the wide submissions data frame to a `*.tsv` file that can be used for uploading the SRA submission website:

# %%
submissions_spreadsheet = 'SRA_submission_spreadsheet.tsv'

submissions_wide.to_csv(submissions_spreadsheet, sep='\t', index=False)

# %% [markdown]
# We also want to write a file with all of the FASTQ files that are in the submission spreadsheet:

# %%
fastq_file_list = 'FASTQs_to_upload.csv'

print(f"Writing list of all the FASTQ files to upload to {fastq_file_list}")

(submissions_tidy
 [['filename_fullpath', 'filename']]
 .to_csv(fastq_file_list, index=False)
 )
# Out:
# Writing list of all the FASTQ files to upload to FASTQs_to_upload.csv
